# %% [markdown]
# # 피규어 출력

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import sys

# %%
#시각화 패키지들
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
from statsmodels.graphics.mosaicplot import mosaic

plt.style.use("ggplot")

# %%
#분석 관련
from scipy.stats import chi2_contingency
from scipy.stats import kstest
from statsmodels.formula.api import ols
from factor_analyzer import FactorAnalyzer

# %%
# random forest 결과
rf_recalls=[0.574,0.574,0.574,0.78,0.617,0.553,0.8,0.553,0.596,0.76,0.553,0.596]
rf_accs=[0.6595,0.691,0.691,0.52,0.745,0.702,0.638,0.713,0.702,0.6489,0.713,0.7002]
rf_specificity=[0.745,0.808,0.808,0.26,0.873,0.851,0.476,0.873,0.808,0.5378,0.873,0.8044]

# %%
Acc_df=pd.DataFrame({"baseline":rf_accs[:3],
              "10":rf_accs[3:6], 
              "15":rf_accs[6:9], 
              "20":rf_accs[9:12],})
Acc_df.plot()
# Out:
# <AxesSubplot:>

# %%
rf_accs[3:6]
# Out:
# [0.52, 0.745, 0.702]

# %%
stat_recalls=[0.574,0.574,0.574,0.7,0.617,0.553,0.83,0.59,0.596,0.74,0.596,0.617]
stat_accs=[0.6595,0.691,0.691,0.606,0.745,0.67,0.638,0.702,0.66,0.606,0.702,0.681]
stat_specificty=[0.745,0.808,0.808,0.512,0.873,0.787,0.446,0.814,0.724,0.472,0.808,0.745]

# %%
#acc 그래프
plt.figure(figsize=(12, 8))
x_ind = ['baseline','10','15','17','20']
plt.plot(rf_accs[1,4,])

# %%
#recall 그래프

# %%
#specificty 그래프
